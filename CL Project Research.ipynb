# %%
import pandas as pd

# %%
rotten_tomatoes_data = pd.read_csv('data/zippedData/rotten_tomatoes_critic_reviews.csv.gz')
rotten_tomatoes_data.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# ...

# %%
rotten_tomatoes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130017 entries, 0 to 1130016
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   rotten_tomatoes_link  1130017 non-null  object
#  1   critic_name           1111488 non-null  object
#  2   top_critic            1130017 non-null  bool
#  3   publisher_name        1130017 non-null  object
#  4   review_type           1130017 non-null  object
#  5   review_score          824081 non-null   object
#  6   review_date           1130017 non-null  object
#  7   review_content        1064211 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 61.4+ MB

# %%
rotten_tomatoes_data = rotten_tomatoes_data.dropna(subset = ['review_score'])

# %%
rotten_tomatoes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 824081 entries, 3 to 1130016
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   rotten_tomatoes_link  824081 non-null  object
#  1   critic_name           809598 non-null  object
#  2   top_critic            824081 non-null  bool
#  3   publisher_name        824081 non-null  object
#  4   review_type           824081 non-null  object
#  5   review_score          824081 non-null  object
#  6   review_date           824081 non-null  object
#  7   review_content        758709 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 51.1+ MB

# %%
rotten_tomatoes_data['review_score'].value_counts()
# Out:
# 3/5          90273
# 4/5          83659
# 3/4          72366
# 2/5          60174
# 2/4          47546
#              ...
# 3.55/10          1
# 8.485/10         1
# 7.0155/10        1
# 3.5/3            1
# 9.78/10          1
# Name: review_score, Length: 814, dtype: int64

# %%
rotten_tomatoes_data['review_score'].to_numeric()
rotten_tomatoes_data.to_numeric(rotten_tomatoes_data['review_score'], downcast="float")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-e4842aaaa959> in <module>
# ----> 1 rotten_tomatoes_data['review_score'].to_numeric()
#       2 rotten_tomatoes_data.to_numeric(rotten_tomatoes_data['review_score'], downcast="float")
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
rt_movies_data = pd.read_csv('data/zippedData/rotten_tomatoes_movies.csv.gz')
rt_movies_data.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...
