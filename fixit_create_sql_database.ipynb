# %% [markdown]
# # Purpose
#
# Students have the option of using Pandas and SQL to complete this project. A Phase 1 project done completely in pandas, completely in SQL, or a mixture of the two can all be considered a fine Phase 1 project. This notebook serves as a resource for setting up an SQL database for students who wish to use SQL in their Phase 1 project.
#
# **To create the `movies.db` database, run the code cells below.**
# > The Entity Relational Diagram is below

# %%
from src.make_db import create_movies_db

# %%
create_movies_db()
# Out:
# imdb_title_principals table created successfully....
# imdb_name_basic table created successfully....
# imdb_title_crew table created successfully....
# imdb_title_ratings table created successfully....
# imdb_title_basics table created successfully....
# imdb_title_akas table created successfully....
# tn_movie_budgets table created successfully....
# tmdb_movies table created successfully....
# bom_movie_gross table created successfully....
# rotten_tomatoes_critic_reviews table created successfully....
# rotten_tomatoes_movies table created successfully....
# =========================================================
# Inserting data into the imdb_title_crew table....
# Inserting data into the tmdb_movies table....
# Inserting data into the imdb_title_akas table....
# Inserting data into the imdb_title_ratings table....
# Inserting data into the imdb_name_basics table....
# Inserting data into the rotten_tomatoes_movies table....
# Inserting data into the rotten_tomatoes_critic_reviews table....
# Inserting data into the imdb_title_basics table....
# Inserting data into the tn_movie_budgets table....
# Inserting data into the bom_movie_gross table....
# Inserting data into the imdb_title_principals table....
# =========================================================
# Database created successfully!
# To connect to the database: open a connection using the path "data/movies.db"

# %% [markdown]
# ![movies.db schema](images/movies_db_schema.png)

# %%
import os
import sqlite3
import pandas as pd
# Open up a connection
conn = sqlite3.connect('data/movies.db')
# Initialize a cursor
cursor = conn.cursor()

# %%
budgets = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz') #load data
budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
budgets['domestic_gross'] = budgets['domestic_gross'].replace({'\$': '', ',': ''}, regex=True).astype(float) #change to float to order by
budgets['worldwide_gross'] = budgets['worldwide_gross'].replace({'\$': '', ',': ''}, regex=True).astype(float)
budgets['production_budget'] = budgets['production_budget'].replace({'\$': '', ',': ''}, regex=True).astype(float)

# %%
budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 271.2+ KB

# %%
table_name_query = """SELECT * FROM tn_movie_budgets ORDER BY `production_budget`+0 DESC;"""

pd.read_sql(table_name_query, conn)
# Out:
#        idx  id  release_date                                        movie  \
# 0        0   1  Dec 18, 2009                                       Avatar
# 1        1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2        2   3   Jun 7, 2019                                 Dark Phoenix
# 3        3   4   May 1, 2015                      Avengers: Age of Ultron
# 4        4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...    ...  ..           ...                                          ...
# 5777  5777  78  Dec 31, 2018                                       Red 11
# 5778  5778  79   Apr 2, 1999                                    Following
# 5779  5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 7 columns]

# %%
budgets['end_gross'] = budgets['domestic_gross'] + budgets['worldwide_gross'] - budgets['production_budget'] 
budgets.head() # calculated end gross
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross     end_gross
# 0        425000000.0     760507625.0     2.776345e+09  3.111853e+09
# 1        410600000.0     241063875.0     1.045664e+09  8.761278e+08
# 2        350000000.0      42762350.0     1.497624e+08 -1.574753e+08
# 3        330600000.0     459005868.0     1.403014e+09  1.531420e+09
# 4        317000000.0     620181382.0     1.316722e+09  1.619903e+09

# %%
budgets = budgets.sort_values(by='end_gross', ascending=False)
budgets
# Out:
#      id  release_date                                 movie  \
# 0     1  Dec 18, 2009                                Avatar
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 42   43  Dec 19, 1997                               Titanic
# 6     7  Apr 27, 2018                Avengers: Infinity War
# 33   34  Jun 12, 2015                        Jurassic World
# ..   ..           ...                                   ...
# 480  81  Dec 31, 2019                      Army of the Dead
# 479  80  Dec 13, 2017                                Bright
# 341  42  Jun 14, 2019           Men in Black: International
# 194  95  Dec 31, 2020                              Moonfall
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross     end_gross
# 0          425000000.0     760507625.0     2.776345e+09  3.111853e+09
# 5          306000000.0     936662225.0     2.053311e+09  2.683973e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.667572e+09
# 6          300000000.0     678815482.0     2.048134e+09  2.426950e+09
# 33         215000000.0     652270625.0     1.648855e+09  2.086125e+09
# ..                 ...             ...              ...           ...
# 480         90000000.0             0.0     0.000000e+00 -9.000000e+07
# 479         90000000.0             0.0     0.000000e+00 -9.000000e+07
# 341        110000000.0       3100000.0     3.100000e+06 -1.038000e+08
# 194        150000000.0             0.0     0.000000e+00 -1.500000e+08
# 2          350000000.0      42762350.0     1.497624e+08 -1.574753e+08
#
# [5782 rows x 7 columns]

# %%
type(budgets)
# Out:
# pandas.core.frame.DataFrame

# %%
stream_platform = pd.read_csv('data/MoviesOnStreamingPlatforms_updated.csv')
stream_platform
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87%        1     0            0        0     0
# 1                 87%        1     0            0        0     0
# 2                 84%        1     0            0        0     0
# 3                 96%        1     0            0        0     0
# 4                 97%        1     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16739             NaN        0     0            0        1     0
# 16740             NaN        0     0            0        1     0
# 16741             NaN        0     0            0        1     0
# 16742             NaN        0     0            0        1     0
# 16743             NaN        0     0            0        1     0
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1      Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2             Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                     Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                        Sergio Leone                           Western
# ...                               ...                               ...
# 16739                    Bruce Bilson      Comedy,Family,Fantasy,Horror
# 16740                     Neal Israel              Comedy,Family,Sci-Fi
# 16741                    Neil Gelinas                       Documentary
# 16742            Richard Slater-Jones                       Documentary
# 16743                     James Algar          Documentary,Short,Family
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16739                 United States                  English    120.0
# 16740                 United States                  English     90.0
# 16741                 United States                  English      NaN
# 16742                 United States                  English      NaN
# 16743                 United States                  English     32.0
#
# [16744 rows x 17 columns]

# %%
stream_platform = stream_platform.dropna(subset = ['Rotten Tomatoes'])
stream_platform
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16671       16671  16672          George of the Jungle 2  2003   7+   3.3
# 16677       16677  16678                   That Darn Cat  1997   7+   4.7
# 16687       16687  16688                          Kazaam  1996   7+   3.0
# 16705       16705  16706                Meet the Deedles  1998   7+   4.1
# 16719       16719  16720                      Pocahontas  1995  NaN   5.3
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                 87%        1     0            0        0     0
# 1                 87%        1     0            0        0     0
# 2                 84%        1     0            0        0     0
# 3                 96%        1     0            0        0     0
# 4                 97%        1     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16671             17%        0     0            0        1     0
# 16677             13%        0     0            0        1     0
# 16687              6%        0     0            0        1     0
# 16705              7%        0     0            0        1     0
# 16719             55%        0     0            0        1     0
#
#                             Directors  \
# 0                   Christopher Nolan
# 1      Lana Wachowski,Lilly Wachowski
# 2             Anthony Russo,Joe Russo
# 3                     Robert Zemeckis
# 4                        Sergio Leone
# ...                               ...
# 16671                  David Grossman
# 16677                Robert Stevenson
# 16687             Paul Michael Glaser
# 16705                     Steve Boyum
# 16719      Mike Gabriel,Eric Goldberg
#
#                                                  Genres  \
# 0                      Action,Adventure,Sci-Fi,Thriller
# 1                                         Action,Sci-Fi
# 2                               Action,Adventure,Sci-Fi
# 3                               Adventure,Comedy,Sci-Fi
# 4                                               Western
# ...                                                 ...
# 16671                           Adventure,Comedy,Family
# 16677                      Comedy,Crime,Family,Thriller
# 16687                     Comedy,Family,Fantasy,Musical
# 16705                                     Comedy,Family
# 16719  Animation,Adventure,Drama,Family,Musical,Romance
#
#                             Country                 Language  Runtime
# 0      United States,United Kingdom  English,Japanese,French    148.0
# 1                     United States                  English    136.0
# 2                     United States                  English    149.0
# 3                     United States                  English    116.0
# 4          Italy,Spain,West Germany                  Italian    161.0
# ...                             ...                      ...      ...
# 16671       United States,Australia                  English     87.0
# 16677                 United States           English,French    116.0
# 16687                 United States                  English     93.0
# 16705                 United States                  English     93.0
# 16719                 United States        English,Algonquin     81.0
#
# [5158 rows x 17 columns]

# %%
stream_platform['Title']
# Out:
# 0                             Inception
# 1                            The Matrix
# 2                Avengers: Infinity War
# 3                    Back to the Future
# 4        The Good, the Bad and the Ugly
#                       ...
# 16671            George of the Jungle 2
# 16677                     That Darn Cat
# 16687                            Kazaam
# 16705                  Meet the Deedles
# 16719                        Pocahontas
# Name: Title, Length: 5158, dtype: object

# %%
stream_title = stream_platform['Title']

# %%
budgets['movie']
# Out:
# 0                                    Avatar
# 5      Star Wars Ep. VII: The Force Awakens
# 42                                  Titanic
# 6                    Avengers: Infinity War
# 33                           Jurassic World
#                        ...
# 480                        Army of the Dead
# 479                                  Bright
# 341             Men in Black: International
# 194                                Moonfall
# 2                              Dark Phoenix
# Name: movie, Length: 5782, dtype: object

# %%
data_title = budgets['movie']

# %%
stream_platform[stream_platform['Title'].isin(data_title)]
# Out:
#        Unnamed: 0     ID                                 Title  Year  Age  \
# 0               0      1                             Inception  2010  13+
# 1               1      2                            The Matrix  1999  18+
# 2               2      3                Avengers: Infinity War  2018  13+
# 3               3      4                    Back to the Future  1985   7+
# 6               6      7                           The Pianist  2002  18+
# ...           ...    ...                                   ...   ...  ...
# 16552       16552  16553  Confessions of a Teenage Drama Queen  2004   7+
# 16633       16633  16634                     The Country Bears  2002  all
# 16643       16643  16644                      Doug's 1st Movie  1999  all
# 16705       16705  16706                      Meet the Deedles  1998   7+
# 16719       16719  16720                            Pocahontas  1995  NaN
#
#        IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0       8.8             87%        1     0            0        0     0
# 1       8.7             87%        1     0            0        0     0
# 2       8.5             84%        1     0            0        0     0
# 3       8.5             96%        1     0            0        0     0
# 6       8.5             95%        1     0            1        0     0
# ...     ...             ...      ...   ...          ...      ...   ...
# 16552   4.6             14%        0     0            0        1     0
# 16633   4.1             29%        0     0            0        1     0
# 16643   5.0             26%        0     0            0        1     0
# 16705   4.1              7%        0     0            0        1     0
# 16719   5.3             55%        0     0            0        1     0
#
#                             Directors  \
# 0                   Christopher Nolan
# 1      Lana Wachowski,Lilly Wachowski
# 2             Anthony Russo,Joe Russo
# 3                     Robert Zemeckis
# 6                      Roman Polanski
# ...                               ...
# 16552                   Sara Sugarman
# 16633                  Peter Hastings
# 16643                   Maurice Joyce
# 16705                     Steve Boyum
# 16719      Mike Gabriel,Eric Goldberg
#
#                                                   Genres  \
# 0                       Action,Adventure,Sci-Fi,Thriller
# 1                                          Action,Sci-Fi
# 2                                Action,Adventure,Sci-Fi
# 3                                Adventure,Comedy,Sci-Fi
# 6                              Biography,Drama,Music,War
# ...                                                  ...
# 16552                        Comedy,Family,Music,Romance
# 16633                        Comedy,Family,Music,Musical
# 16643  Animation,Adventure,Comedy,Drama,Family,Fantas...
# 16705                                      Comedy,Family
# 16719   Animation,Adventure,Drama,Family,Musical,Romance
#
#                                     Country                 Language  Runtime
# 0              United States,United Kingdom  English,Japanese,French    148.0
# 1                             United States                  English    136.0
# 2                             United States                  English    149.0
# 3                             United States                  English    116.0
# 6      United Kingdom,France,Poland,Germany   English,German,Russian    150.0
# ...                                     ...                      ...      ...
# 16552                 Germany,United States                  English     89.0
# 16633                         United States                  English     88.0
# 16643                         United States                  English     77.0
# 16705                         United States                  English     93.0
# 16719                         United States        English,Algonquin     81.0
#
# [988 rows x 17 columns]

# %%
streammoviedata = stream_platform[stream_platform['Title'].isin(data_title)]

# %%
streammovie_titles = streammoviedata['Title']
streammovie_titles
# Out:
# 0                                   Inception
# 1                                  The Matrix
# 2                      Avengers: Infinity War
# 3                          Back to the Future
# 6                                 The Pianist
#                          ...
# 16552    Confessions of a Teenage Drama Queen
# 16633                       The Country Bears
# 16643                        Doug's 1st Movie
# 16705                        Meet the Deedles
# 16719                              Pocahontas
# Name: Title, Length: 988, dtype: object

# %%
stream_platform[~stream_platform['Title'].isin(data_title)]
# Out:
#        Unnamed: 0     ID                              Title  Year  Age  IMDb  \
# 4               4      5     The Good, the Bad and the Ugly  1966  18+   8.8
# 5               5      6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 11             11     12                           3 Idiots  2009  13+   8.4
# 12             12     13                    Pan's Labyrinth  2006  18+   8.2
# 18             18     19                  The King's Speech  2010  18+   8.0
# ...           ...    ...                                ...   ...  ...   ...
# 16637       16637  16638                 Inspector Gadget 2  2003  all   3.4
# 16657       16657  16658       A Kid in King Arthur's Court  1995   7+   4.7
# 16671       16671  16672             George of the Jungle 2  2003   7+   3.3
# 16677       16677  16678                      That Darn Cat  1997   7+   4.7
# 16687       16687  16688                             Kazaam  1996   7+   3.0
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 4                 97%        1     0            1        0     0
# 5                 97%        1     0            0        0     0
# 11               100%        1     0            1        0     0
# 12                95%        1     0            0        0     0
# 18                95%        1     0            0        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16637             40%        0     0            0        1     0
# 16657              5%        0     0            0        1     0
# 16671             17%        0     0            0        1     0
# 16677             13%        0     0            0        1     0
# 16687              6%        0     0            0        1     0
#
#                                          Directors  \
# 4                                     Sergio Leone
# 5      Bob Persichetti,Peter Ramsey,Rodney Rothman
# 11                                 Rajkumar Hirani
# 12                              Guillermo del Toro
# 18                                      Tom Hooper
# ...                                            ...
# 16637                                    Alex Zamm
# 16657                             Michael Gottlieb
# 16671                               David Grossman
# 16677                             Robert Stevenson
# 16687                          Paul Michael Glaser
#
#                                          Genres  \
# 4                                       Western
# 5      Animation,Action,Adventure,Family,Sci-Fi
# 11                                 Comedy,Drama
# 12                            Drama,Fantasy,War
# 18                      Biography,Drama,History
# ...                                         ...
# 16637         Action,Comedy,Crime,Family,Sci-Fi
# 16657   Adventure,Comedy,Family,Fantasy,Romance
# 16671                   Adventure,Comedy,Family
# 16677              Comedy,Crime,Family,Thriller
# 16687             Comedy,Family,Fantasy,Musical
#
#                                       Country         Language  Runtime
# 4                    Italy,Spain,West Germany          Italian    161.0
# 5                               United States  English,Spanish    117.0
# 11                                      India    Hindi,English    170.0
# 12                               Mexico,Spain          Spanish    118.0
# 18     United Kingdom,United States,Australia          English    118.0
# ...                                       ...              ...      ...
# 16637                           United States          English     89.0
# 16657    United States,Hungary,United Kingdom          English     89.0
# 16671                 United States,Australia          English     87.0
# 16677                           United States   English,French    116.0
# 16687                           United States          English     93.0
#
# [4170 rows x 17 columns]

# %%
budgets[budgets['movie'].isin(streammovie_titles)]
# Out:
#       id  release_date                   movie  production_budget  \
# 0      1  Dec 18, 2009                  Avatar        425000000.0
# 6      7  Apr 27, 2018  Avengers: Infinity War        300000000.0
# 26    27   May 4, 2012            The Avengers        225000000.0
# 41    42  Feb 16, 2018           Black Panther        200000000.0
# 43    44  Jun 15, 2018           Incredibles 2        200000000.0
# ...   ..           ...                     ...                ...
# 817   18  Oct 27, 2000           Lucky Numbers         65000000.0
# 434   35   Apr 9, 2004               The Alamo         92000000.0
# 1206   7   Nov 8, 2019             Arctic Dogs         50000000.0
# 193   94  Mar 11, 2011         Mars Needs Moms        150000000.0
# 479   80  Dec 13, 2017                  Bright         90000000.0
#
#       domestic_gross  worldwide_gross     end_gross
# 0        760507625.0     2.776345e+09  3.111853e+09
# 6        678815482.0     2.048134e+09  2.426950e+09
# 26       623279547.0     1.517936e+09  1.916215e+09
# 41       700059566.0     1.348258e+09  1.848318e+09
# 43       608581744.0     1.242521e+09  1.651102e+09
# ...              ...              ...           ...
# 817       10014234.0     1.001423e+07 -4.497153e+07
# 434       22406362.0     2.391136e+07 -4.568228e+07
# 1206             0.0     0.000000e+00 -5.000000e+07
# 193       21392758.0     3.954976e+07 -8.905748e+07
# 479              0.0     0.000000e+00 -9.000000e+07
#
# [1016 rows x 7 columns]

# %%
budgets[~budgets['movie'].isin(streammovie_titles)]
# Out:
#      id  release_date                                 movie  \
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 42   43  Dec 19, 1997                               Titanic
# 33   34  Jun 12, 2015                        Jurassic World
# 66   67   Apr 3, 2015                             Furious 7
# 4     5  Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi
# ..   ..           ...                                   ...
# 404   5  Aug 16, 2002          The Adventures of Pluto Nash
# 480  81  Dec 31, 2019                      Army of the Dead
# 341  42  Jun 14, 2019           Men in Black: International
# 194  95  Dec 31, 2020                              Moonfall
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross     end_gross
# 5          306000000.0     936662225.0     2.053311e+09  2.683973e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.667572e+09
# 33         215000000.0     652270625.0     1.648855e+09  2.086125e+09
# 66         190000000.0     353007020.0     1.518723e+09  1.681730e+09
# 4          317000000.0     620181382.0     1.316722e+09  1.619903e+09
# ..                 ...             ...              ...           ...
# 404        100000000.0       4411102.0     7.094995e+06 -8.849390e+07
# 480         90000000.0             0.0     0.000000e+00 -9.000000e+07
# 341        110000000.0       3100000.0     3.100000e+06 -1.038000e+08
# 194        150000000.0             0.0     0.000000e+00 -1.500000e+08
# 2          350000000.0      42762350.0     1.497624e+08 -1.574753e+08
#
# [4766 rows x 7 columns]

# %%
df = budgets.loc[(budgets['domestic_gross'] > 0.0) & (budgets['worldwide_gross'] > 0.0)]
df
# Out:
#      id  release_date                                 movie  \
# 0     1  Dec 18, 2009                                Avatar
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 42   43  Dec 19, 1997                               Titanic
# 6     7  Apr 27, 2018                Avengers: Infinity War
# 33   34  Jun 12, 2015                        Jurassic World
# ..   ..           ...                                   ...
# 352  53  Apr 27, 2001                        Town & Country
# 404   5  Aug 16, 2002          The Adventures of Pluto Nash
# 193  94  Mar 11, 2011                       Mars Needs Moms
# 341  42  Jun 14, 2019           Men in Black: International
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross     end_gross
# 0          425000000.0     760507625.0     2.776345e+09  3.111853e+09
# 5          306000000.0     936662225.0     2.053311e+09  2.683973e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.667572e+09
# 6          300000000.0     678815482.0     2.048134e+09  2.426950e+09
# 33         215000000.0     652270625.0     1.648855e+09  2.086125e+09
# ..                 ...             ...              ...           ...
# 352        105000000.0       6712451.0     1.036477e+07 -8.792278e+07
# 404        100000000.0       4411102.0     7.094995e+06 -8.849390e+07
# 193        150000000.0      21392758.0     3.954976e+07 -8.905748e+07
# 341        110000000.0       3100000.0     3.100000e+06 -1.038000e+08
# 2          350000000.0      42762350.0     1.497624e+08 -1.574753e+08
#
# [5234 rows x 7 columns]

# %%
nonstream_eg=df[~df['movie'].isin(streammovie_titles)]
nonstream_eg
# Out:
#      id  release_date                                 movie  \
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 42   43  Dec 19, 1997                               Titanic
# 33   34  Jun 12, 2015                        Jurassic World
# 66   67   Apr 3, 2015                             Furious 7
# 4     5  Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi
# ..   ..           ...                                   ...
# 607   8   Sep 2, 2005                    A Sound of Thunder
# 352  53  Apr 27, 2001                        Town & Country
# 404   5  Aug 16, 2002          The Adventures of Pluto Nash
# 341  42  Jun 14, 2019           Men in Black: International
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross     end_gross
# 5          306000000.0     936662225.0     2.053311e+09  2.683973e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.667572e+09
# 33         215000000.0     652270625.0     1.648855e+09  2.086125e+09
# 66         190000000.0     353007020.0     1.518723e+09  1.681730e+09
# 4          317000000.0     620181382.0     1.316722e+09  1.619903e+09
# ..                 ...             ...              ...           ...
# 607         80000000.0       1900451.0     6.300451e+06 -7.179910e+07
# 352        105000000.0       6712451.0     1.036477e+07 -8.792278e+07
# 404        100000000.0       4411102.0     7.094995e+06 -8.849390e+07
# 341        110000000.0       3100000.0     3.100000e+06 -1.038000e+08
# 2          350000000.0      42762350.0     1.497624e+08 -1.574753e+08
#
# [4291 rows x 7 columns]

# %%
df_title = df['movie']

# %%
df_nonstream = stream_platform[~stream_platform['Title'].isin(df_title)]
df_nonstream
# Out:
#        Unnamed: 0     ID                              Title  Year  Age  IMDb  \
# 4               4      5     The Good, the Bad and the Ugly  1966  18+   8.8
# 5               5      6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 11             11     12                           3 Idiots  2009  13+   8.4
# 12             12     13                    Pan's Labyrinth  2006  18+   8.2
# 18             18     19                  The King's Speech  2010  18+   8.0
# ...           ...    ...                                ...   ...  ...   ...
# 16637       16637  16638                 Inspector Gadget 2  2003  all   3.4
# 16657       16657  16658       A Kid in King Arthur's Court  1995   7+   4.7
# 16671       16671  16672             George of the Jungle 2  2003   7+   3.3
# 16677       16677  16678                      That Darn Cat  1997   7+   4.7
# 16687       16687  16688                             Kazaam  1996   7+   3.0
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 4                 97%        1     0            1        0     0
# 5                 97%        1     0            0        0     0
# 11               100%        1     0            1        0     0
# 12                95%        1     0            0        0     0
# 18                95%        1     0            0        0     0
# ...               ...      ...   ...          ...      ...   ...
# 16637             40%        0     0            0        1     0
# 16657              5%        0     0            0        1     0
# 16671             17%        0     0            0        1     0
# 16677             13%        0     0            0        1     0
# 16687              6%        0     0            0        1     0
#
#                                          Directors  \
# 4                                     Sergio Leone
# 5      Bob Persichetti,Peter Ramsey,Rodney Rothman
# 11                                 Rajkumar Hirani
# 12                              Guillermo del Toro
# 18                                      Tom Hooper
# ...                                            ...
# 16637                                    Alex Zamm
# 16657                             Michael Gottlieb
# 16671                               David Grossman
# 16677                             Robert Stevenson
# 16687                          Paul Michael Glaser
#
#                                          Genres  \
# 4                                       Western
# 5      Animation,Action,Adventure,Family,Sci-Fi
# 11                                 Comedy,Drama
# 12                            Drama,Fantasy,War
# 18                      Biography,Drama,History
# ...                                         ...
# 16637         Action,Comedy,Crime,Family,Sci-Fi
# 16657   Adventure,Comedy,Family,Fantasy,Romance
# 16671                   Adventure,Comedy,Family
# 16677              Comedy,Crime,Family,Thriller
# 16687             Comedy,Family,Fantasy,Musical
#
#                                       Country         Language  Runtime
# 4                    Italy,Spain,West Germany          Italian    161.0
# 5                               United States  English,Spanish    117.0
# 11                                      India    Hindi,English    170.0
# 12                               Mexico,Spain          Spanish    118.0
# 18     United Kingdom,United States,Australia          English    118.0
# ...                                       ...              ...      ...
# 16637                           United States          English     89.0
# 16657    United States,Hungary,United Kingdom          English     89.0
# 16671                 United States,Australia          English     87.0
# 16677                           United States   English,French    116.0
# 16687                           United States          English     93.0
#
# [4241 rows x 17 columns]

# %%
df_noncount = df_nonstream.sort_values('Rotten Tomatoes', ascending = False).head(500)
df_noncount
# Out:
#       Unnamed: 0    ID                                              Title  \
# 262          262   263                               20 Feet from Stardom
# 3590        3590  3591                                          Apollo 11
# 3562        3562  3563                                           Parasite
# 4511        4511  4512                                           For Sama
# 4854        4854  4855                                   Rivers and Tides
# ...          ...   ...                                                ...
# 571          571   572  Raiders!: The Story of the Greatest Fan Film E...
# 550          550   551                                   The Confirmation
# 4571        4571  4572                                You Don't Know Jack
# 6509        6509  6510                                    Ghostbox Cowboy
# 4492        4492  4493                                              Pride
#
#       Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  \
# 262   2013  13+   7.4             99%        1     0            0        0
# 3590  2019  all   8.2             99%        0     1            0        0
# 3562  2019  18+   8.6             99%        0     1            1        0
# 4511  2019   7+   8.5             99%        0     0            1        0
# 4854  2001  all   7.9             99%        0     0            1        0
# ...    ...  ...   ...             ...      ...   ...          ...      ...
# 571   2015  NaN   6.9             91%        1     0            0        0
# 550   2016  13+   6.4             91%        1     0            0        0
# 4571  2010  NaN   7.6             91%        0     0            1        0
# 6509  2018  NaN   4.7             91%        0     0            1        0
# 4492  2014  18+   7.8             91%        0     0            1        0
#
#       Type                    Directors  \
# 262      0               Morgan Neville
# 3590     0          Todd Douglas Miller
# 3562     0                 Bong Joon Ho
# 4511     0  Waad Al-Kateab,Edward Watts
# 4854     0         Thomas Riedelsheimer
# ...    ...                          ...
# 571      0      Jeremy Coon,Tim Skousen
# 550      0                   Bob Nelson
# 4571     0               Barry Levinson
# 6509     0              John Maringouin
# 4492     0              Matthew Warchus
#
#                                             Genres  \
# 262                    Documentary,Biography,Music
# 3590                           Documentary,History
# 3562                         Comedy,Drama,Thriller
# 4511                               Documentary,War
# 4854                                   Documentary
# ...                                            ...
# 571                                    Documentary
# 550                                   Comedy,Drama
# 4571                               Biography,Drama
# 6509  Action,Adventure,Comedy,Crime,Drama,Thriller
# 4492        Biography,Comedy,Drama,History,Romance
#
#                                     Country         Language  Runtime
# 262                           United States  English,Spanish     91.0
# 3590                          United States          English     93.0
# 3562                            South Korea   Korean,English    132.0
# 4511     United Kingdom,Syria,United States   Arabic,English    100.0
# 4854  Germany,Finland,United Kingdom,Canada          English     90.0
# ...                                     ...              ...      ...
# 571                           United States          English    106.0
# 550                                  Canada          English    101.0
# 4571                          United States          English    134.0
# 6509                    China,United States          English     90.0
# 4492    United Kingdom,France,United States    English,Welsh    119.0
#
# [500 rows x 17 columns]

# %%
df_noncount_list = df_noncount['Title']
df_noncount_list
# Out:
# 262                                  20 Feet from Stardom
# 3590                                            Apollo 11
# 3562                                             Parasite
# 4511                                             For Sama
# 4854                                     Rivers and Tides
#                               ...
# 571     Raiders!: The Story of the Greatest Fan Film E...
# 550                                      The Confirmation
# 4571                                  You Don't Know Jack
# 6509                                      Ghostbox Cowboy
# 4492                                                Pride
# Name: Title, Length: 500, dtype: object

# %%
nonstream_eg.describe() #not on stream avg end gross
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  4291.000000       4.291000e+03    4.291000e+03     4.291000e+03
# mean     50.186204       3.243548e+07    4.344763e+07     9.425513e+07
# std      28.836660       4.005439e+07    6.501099e+07     1.661247e+08
# min       1.000000       1.100000e+03    4.010000e+02     4.010000e+02
# 25%      25.000000       6.000000e+06    4.000000e+06     7.833752e+06
# 50%      50.000000       1.940000e+07    2.096664e+07     3.346201e+07
# 75%      75.000000       4.100000e+07    5.507109e+07     1.044966e+08
# max     100.000000       3.500000e+08    9.366622e+08     2.208208e+09
#
#           end_gross
# count  4.291000e+03
# mean   1.052673e+08
# std    2.017095e+08
# min   -1.574753e+08
# 25%    1.243676e+06
# 50%    3.250004e+07
# 75%    1.200958e+08
# max    2.683973e+09

# %%
onstream_eg=df[df['movie'].isin(streammovie_titles)]
onstream_eg
# Out:
#       id  release_date                                 movie  \
# 0      1  Dec 18, 2009                                Avatar
# 6      7  Apr 27, 2018                Avengers: Infinity War
# 26    27   May 4, 2012                          The Avengers
# 41    42  Feb 16, 2018                         Black Panther
# 43    44  Jun 15, 2018                         Incredibles 2
# ...   ..           ...                                   ...
# 748   49  May 28, 2010                                 Agora
# 1781  82  Jul 31, 2015  The Young and Prodigious T.S. Spivet
# 817   18  Oct 27, 2000                         Lucky Numbers
# 434   35   Apr 9, 2004                             The Alamo
# 193   94  Mar 11, 2011                       Mars Needs Moms
#
#       production_budget  domestic_gross  worldwide_gross     end_gross
# 0           425000000.0     760507625.0     2.776345e+09  3.111853e+09
# 6           300000000.0     678815482.0     2.048134e+09  2.426950e+09
# 26          225000000.0     623279547.0     1.517936e+09  1.916215e+09
# 41          200000000.0     700059566.0     1.348258e+09  1.848318e+09
# 43          200000000.0     608581744.0     1.242521e+09  1.651102e+09
# ...                 ...             ...              ...           ...
# 748          70000000.0        619423.0     3.899229e+07 -3.038828e+07
# 1781         33000000.0        176847.0     3.576870e+05 -3.246547e+07
# 817          65000000.0      10014234.0     1.001423e+07 -4.497153e+07
# 434          92000000.0      22406362.0     2.391136e+07 -4.568228e+07
# 193         150000000.0      21392758.0     3.954976e+07 -8.905748e+07
#
# [943 rows x 7 columns]

# %%
onstream_eg.describe() #on stream avg end gross
# Out:
#                id  production_budget  domestic_gross  worldwide_gross  \
# count  943.000000       9.430000e+02    9.430000e+02     9.430000e+02
# mean    51.076352       4.130498e+07    5.904326e+07     1.303679e+08
# std     28.907321       5.368128e+07    8.946631e+07     2.355588e+08
# min      1.000000       3.000000e+04    3.880000e+02     7.030000e+02
# 25%     26.000000       7.150000e+06    5.978240e+06     1.074536e+07
# 50%     51.000000       2.000000e+07    2.808716e+07     4.715865e+07
# 75%     76.500000       5.000000e+07    7.216403e+07     1.408390e+08
# max    100.000000       4.250000e+08    7.605076e+08     2.776345e+09
#
#           end_gross
# count  9.430000e+02
# mean   1.481062e+08
# std    2.803931e+08
# min   -8.905748e+07
# 25%    5.436333e+06
# 50%    4.744992e+07
# 75%    1.627550e+08
# max    3.111853e+09

# %%
df_stream = stream_platform[stream_platform['Title'].isin(df_title)]
df_stream
# Out:
#        Unnamed: 0     ID                                 Title  Year  Age  \
# 0               0      1                             Inception  2010  13+
# 1               1      2                            The Matrix  1999  18+
# 2               2      3                Avengers: Infinity War  2018  13+
# 3               3      4                    Back to the Future  1985   7+
# 6               6      7                           The Pianist  2002  18+
# ...           ...    ...                                   ...   ...  ...
# 16552       16552  16553  Confessions of a Teenage Drama Queen  2004   7+
# 16633       16633  16634                     The Country Bears  2002  all
# 16643       16643  16644                      Doug's 1st Movie  1999  all
# 16705       16705  16706                      Meet the Deedles  1998   7+
# 16719       16719  16720                            Pocahontas  1995  NaN
#
#        IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0       8.8             87%        1     0            0        0     0
# 1       8.7             87%        1     0            0        0     0
# 2       8.5             84%        1     0            0        0     0
# 3       8.5             96%        1     0            0        0     0
# 6       8.5             95%        1     0            1        0     0
# ...     ...             ...      ...   ...          ...      ...   ...
# 16552   4.6             14%        0     0            0        1     0
# 16633   4.1             29%        0     0            0        1     0
# 16643   5.0             26%        0     0            0        1     0
# 16705   4.1              7%        0     0            0        1     0
# 16719   5.3             55%        0     0            0        1     0
#
#                             Directors  \
# 0                   Christopher Nolan
# 1      Lana Wachowski,Lilly Wachowski
# 2             Anthony Russo,Joe Russo
# 3                     Robert Zemeckis
# 6                      Roman Polanski
# ...                               ...
# 16552                   Sara Sugarman
# 16633                  Peter Hastings
# 16643                   Maurice Joyce
# 16705                     Steve Boyum
# 16719      Mike Gabriel,Eric Goldberg
#
#                                                   Genres  \
# 0                       Action,Adventure,Sci-Fi,Thriller
# 1                                          Action,Sci-Fi
# 2                                Action,Adventure,Sci-Fi
# 3                                Adventure,Comedy,Sci-Fi
# 6                              Biography,Drama,Music,War
# ...                                                  ...
# 16552                        Comedy,Family,Music,Romance
# 16633                        Comedy,Family,Music,Musical
# 16643  Animation,Adventure,Comedy,Drama,Family,Fantas...
# 16705                                      Comedy,Family
# 16719   Animation,Adventure,Drama,Family,Musical,Romance
#
#                                     Country                 Language  Runtime
# 0              United States,United Kingdom  English,Japanese,French    148.0
# 1                             United States                  English    136.0
# 2                             United States                  English    149.0
# 3                             United States                  English    116.0
# 6      United Kingdom,France,Poland,Germany   English,German,Russian    150.0
# ...                                     ...                      ...      ...
# 16552                 Germany,United States                  English     89.0
# 16633                         United States                  English     88.0
# 16643                         United States                  English     77.0
# 16705                         United States                  English     93.0
# 16719                         United States        English,Algonquin     81.0
#
# [917 rows x 17 columns]

# %%
df_count = df_stream.sort_values('Rotten Tomatoes', ascending = False)
df_count
# Out:
#        Unnamed: 0     ID                       Title  Year  Age  IMDb  \
# 4447         4447   4448                   Lady Bird  2017  18+   7.4
# 16220       16220  16221                Finding Nemo  2003  all   8.1
# 4474         4474   4475                Eighth Grade  2018  18+   7.4
# 3739         3739   3740                      Gloria  2013  18+   6.8
# 4534         4534   4535         I Am Not Your Negro  2017  18+   7.8
# ...           ...    ...                         ...   ...  ...   ...
# 6707         6707   6708         Unfinished Business  2015  18+   5.4
# 3974         3974   3975                  House of D  2004  13+   7.0
# 6036         6036   6037                     Killers  2010  13+   5.4
# 1702         1702   1703                 The Watcher  2000  18+   5.3
# 1419         1419   1420  Silent Hill: Revelation 3D  2012  18+   5.0
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 4447              99%        0     0            1        0     0
# 16220             99%        0     0            0        1     0
# 4474              99%        0     0            1        0     0
# 3739              99%        0     1            0        0     0
# 4534              99%        0     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 6707              10%        0     0            1        0     0
# 3974              10%        0     1            1        0     0
# 6036              10%        0     0            1        0     0
# 1702              10%        1     0            0        0     0
# 1419              10%        1     0            0        0     0
#
#                         Directors                             Genres  \
# 4447                 Greta Gerwig                       Comedy,Drama
# 16220  Andrew Stanton,Lee Unkrich  Animation,Adventure,Comedy,Family
# 4474                   Bo Burnham                       Comedy,Drama
# 3739                 Edward Zwick        Biography,Drama,History,War
# 4534                   Raoul Peck                        Documentary
# ...                           ...                                ...
# 6707                    Ken Scott                       Comedy,Drama
# 3974               David Duchovny                       Comedy,Drama
# 6036               Robert Luketic     Action,Comedy,Romance,Thriller
# 1702                   Tim Hunter                   Mystery,Thriller
# 1419                 M.J. Bassett                             Horror
#
#                                         Country         Language  Runtime
# 4447                              United States  English,Spanish     94.0
# 16220                   United States,Australia          English    100.0
# 4474                              United States          English     93.0
# 3739                              United States          English    122.0
# 4534   Switzerland,France,Belgium,United States   English,French     93.0
# ...                                         ...              ...      ...
# 6707                              United States          English     91.0
# 3974                              United States   English,French     97.0
# 6036                              United States          English    100.0
# 1702                       Canada,United States          English    103.0
# 1419                        Canada,France,Japan          English     95.0
#
# [917 rows x 17 columns]

# %%
df_count[df_count.Title == 'Avatar']
# Out:
#        Unnamed: 0     ID   Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 16236       16236  16237  Avatar  2009  13+   7.8             82%        0
#
#        Hulu  Prime Video  Disney+  Type Directors  \
# 16236     0            0        1     0       NaN
#
#                                                   Genres        Country  \
# 16236  Animation,Action,Adventure,Family,Fantasy,Mystery  United States
#
#       Language  Runtime
# 16236  English     23.0

# %%
df_count_list = df_count['Title']
df_count_list
# Out:
# 4447                      Lady Bird
# 16220                  Finding Nemo
# 4474                   Eighth Grade
# 3739                         Gloria
# 4534            I Am Not Your Negro
#                     ...
# 6707            Unfinished Business
# 3974                     House of D
# 6036                        Killers
# 1702                    The Watcher
# 1419     Silent Hill: Revelation 3D
# Name: Title, Length: 917, dtype: object

# %%
dfbudgetfilter = df[df['movie'].isin(df_count_list)] #514 end_gross of top 500
dfbudgetfilter
# Out:
#       id  release_date                                 movie  \
# 0      1  Dec 18, 2009                                Avatar
# 6      7  Apr 27, 2018                Avengers: Infinity War
# 26    27   May 4, 2012                          The Avengers
# 41    42  Feb 16, 2018                         Black Panther
# 43    44  Jun 15, 2018                         Incredibles 2
# ...   ..           ...                                   ...
# 748   49  May 28, 2010                                 Agora
# 1781  82  Jul 31, 2015  The Young and Prodigious T.S. Spivet
# 817   18  Oct 27, 2000                         Lucky Numbers
# 434   35   Apr 9, 2004                             The Alamo
# 193   94  Mar 11, 2011                       Mars Needs Moms
#
#       production_budget  domestic_gross  worldwide_gross     end_gross
# 0           425000000.0     760507625.0     2.776345e+09  3.111853e+09
# 6           300000000.0     678815482.0     2.048134e+09  2.426950e+09
# 26          225000000.0     623279547.0     1.517936e+09  1.916215e+09
# 41          200000000.0     700059566.0     1.348258e+09  1.848318e+09
# 43          200000000.0     608581744.0     1.242521e+09  1.651102e+09
# ...                 ...             ...              ...           ...
# 748          70000000.0        619423.0     3.899229e+07 -3.038828e+07
# 1781         33000000.0        176847.0     3.576870e+05 -3.246547e+07
# 817          65000000.0      10014234.0     1.001423e+07 -4.497153e+07
# 434          92000000.0      22406362.0     2.391136e+07 -4.568228e+07
# 193         150000000.0      21392758.0     3.954976e+07 -8.905748e+07
#
# [943 rows x 7 columns]

# %%
dfbudgetfilter['Year'] = pd.DatetimeIndex(dfbudgetfilter['release_date']).year
dfbudgetfilter
# Out:
# <ipython-input-43-af6d990da978>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfbudgetfilter['Year'] = pd.DatetimeIndex(dfbudgetfilter['release_date']).year
#       id  release_date                                 movie  \
# 0      1  Dec 18, 2009                                Avatar
# 6      7  Apr 27, 2018                Avengers: Infinity War
# 26    27   May 4, 2012                          The Avengers
# 41    42  Feb 16, 2018                         Black Panther
# 43    44  Jun 15, 2018                         Incredibles 2
# ...   ..           ...                                   ...
# 748   49  May 28, 2010                                 Agora
# 1781  82  Jul 31, 2015  The Young and Prodigious T.S. Spivet
# 817   18  Oct 27, 2000                         Lucky Numbers
# 434   35   Apr 9, 2004                             The Alamo
# 193   94  Mar 11, 2011                       Mars Needs Moms
#
#       production_budget  domestic_gross  worldwide_gross     end_gross  Year
# 0           425000000.0     760507625.0     2.776345e+09  3.111853e+09  2009
# 6           300000000.0     678815482.0     2.048134e+09  2.426950e+09  2018
# 26          225000000.0     623279547.0     1.517936e+09  1.916215e+09  2012
# 41          200000000.0     700059566.0     1.348258e+09  1.848318e+09  2018
# 43          200000000.0     608581744.0     1.242521e+09  1.651102e+09  2018
# ...                 ...             ...              ...           ...   ...
# 748          70000000.0        619423.0     3.899229e+07 -3.038828e+07  2010
# 1781         33000000.0        176847.0     3.576870e+05 -3.246547e+07  2015
# 817          65000000.0      10014234.0     1.001423e+07 -4.497153e+07  2000
# 434          92000000.0      22406362.0     2.391136e+07 -4.568228e+07  2004
# 193         150000000.0      21392758.0     3.954976e+07 -8.905748e+07  2011
#
# [943 rows x 8 columns]

# %%
df_count = df_count.rename(columns={"Title": "movie"})
df_count
# Out:
#        Unnamed: 0     ID                       movie  Year  Age  IMDb  \
# 4447         4447   4448                   Lady Bird  2017  18+   7.4
# 16220       16220  16221                Finding Nemo  2003  all   8.1
# 4474         4474   4475                Eighth Grade  2018  18+   7.4
# 3739         3739   3740                      Gloria  2013  18+   6.8
# 4534         4534   4535         I Am Not Your Negro  2017  18+   7.8
# ...           ...    ...                         ...   ...  ...   ...
# 6707         6707   6708         Unfinished Business  2015  18+   5.4
# 3974         3974   3975                  House of D  2004  13+   7.0
# 6036         6036   6037                     Killers  2010  13+   5.4
# 1702         1702   1703                 The Watcher  2000  18+   5.3
# 1419         1419   1420  Silent Hill: Revelation 3D  2012  18+   5.0
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 4447              99%        0     0            1        0     0
# 16220             99%        0     0            0        1     0
# 4474              99%        0     0            1        0     0
# 3739              99%        0     1            0        0     0
# 4534              99%        0     0            1        0     0
# ...               ...      ...   ...          ...      ...   ...
# 6707              10%        0     0            1        0     0
# 3974              10%        0     1            1        0     0
# 6036              10%        0     0            1        0     0
# 1702              10%        1     0            0        0     0
# 1419              10%        1     0            0        0     0
#
#                         Directors                             Genres  \
# 4447                 Greta Gerwig                       Comedy,Drama
# 16220  Andrew Stanton,Lee Unkrich  Animation,Adventure,Comedy,Family
# 4474                   Bo Burnham                       Comedy,Drama
# 3739                 Edward Zwick        Biography,Drama,History,War
# 4534                   Raoul Peck                        Documentary
# ...                           ...                                ...
# 6707                    Ken Scott                       Comedy,Drama
# 3974               David Duchovny                       Comedy,Drama
# 6036               Robert Luketic     Action,Comedy,Romance,Thriller
# 1702                   Tim Hunter                   Mystery,Thriller
# 1419                 M.J. Bassett                             Horror
#
#                                         Country         Language  Runtime
# 4447                              United States  English,Spanish     94.0
# 16220                   United States,Australia          English    100.0
# 4474                              United States          English     93.0
# 3739                              United States          English    122.0
# 4534   Switzerland,France,Belgium,United States   English,French     93.0
# ...                                         ...              ...      ...
# 6707                              United States          English     91.0
# 3974                              United States   English,French     97.0
# 6036                              United States          English    100.0
# 1702                       Canada,United States          English    103.0
# 1419                        Canada,France,Japan          English     95.0
#
# [917 rows x 17 columns]

# %%
last_data = df_count.merge(dfbudgetfilter, on=['movie', 'Year'])
last_data
# Out:
#      Unnamed: 0     ID                       movie  Year  Age  IMDb  \
# 0          4447   4448                   Lady Bird  2017  18+   7.4
# 1         16220  16221                Finding Nemo  2003  all   8.1
# 2          4474   4475                Eighth Grade  2018  18+   7.4
# 3          4534   4535         I Am Not Your Negro  2017  18+   7.8
# 4         16222  16223                 Toy Story 3  2010  all   8.3
# ..          ...    ...                         ...   ...  ...   ...
# 750       16251  16252                Mary Poppins  1964  all   7.8
# 751        6707   6708         Unfinished Business  2015  18+   5.4
# 752        6036   6037                     Killers  2010  13+   5.4
# 753        1702   1703                 The Watcher  2000  18+   5.3
# 754        1419   1420  Silent Hill: Revelation 3D  2012  18+   5.0
#
#     Rotten Tomatoes  Netflix  Hulu  Prime Video  ...  \
# 0               99%        0     0            1  ...
# 1               99%        0     0            0  ...
# 2               99%        0     0            1  ...
# 3               99%        0     0            1  ...
# 4               98%        0     0            0  ...
# ..              ...      ...   ...          ...  ...
# 750            100%        0     0            0  ...
# 751             10%        0     0            1  ...
# 752             10%        0     0            1  ...
# 753             10%        1     0            0  ...
# 754             10%        1     0            0  ...
#
#                                         Genres  \
# 0                                 Comedy,Drama
# 1            Animation,Adventure,Comedy,Family
# 2                                 Comedy,Drama
# 3                                  Documentary
# 4    Animation,Adventure,Comedy,Family,Fantasy
# ..                                         ...
# 750              Comedy,Family,Fantasy,Musical
# 751                               Comedy,Drama
# 752             Action,Comedy,Romance,Thriller
# 753                           Mystery,Thriller
# 754                                     Horror
#
#                                       Country         Language Runtime  id  \
# 0                               United States  English,Spanish    94.0  53
# 1                     United States,Australia          English   100.0  25
# 2                               United States          English    93.0  95
# 3    Switzerland,France,Belgium,United States   English,French    93.0  32
# 4                               United States  English,Spanish   103.0  47
# ..                                        ...              ...     ...  ..
# 750                             United States          English   139.0  17
# 751                             United States          English    91.0  32
# 752                             United States          English   100.0  54
# 753                      Canada,United States          English   103.0  77
# 754                       Canada,France,Japan          English    95.0   5
#
#      release_date  production_budget  domestic_gross worldwide_gross  \
# 0     Nov 3, 2017         10000000.0      48958273.0    7.861077e+07
# 1    May 30, 2003         94000000.0     380529370.0    9.364294e+08
# 2    Jul 13, 2018          2000000.0      13539710.0    1.434102e+07
# 3     Feb 3, 2017          1000000.0       7123919.0    9.617402e+06
# 4    Jun 18, 2010        200000000.0     415004880.0    1.068880e+09
# ..            ...                ...             ...             ...
# 750  Aug 26, 1964          6000000.0     102272145.0    1.022721e+08
# 751   Mar 6, 2015         35000000.0      10219501.0    1.321405e+07
# 752   Jun 4, 2010         75000000.0      47059963.0    9.557275e+07
# 753   Sep 8, 2000         33000000.0      28946615.0    4.726783e+07
# 754  Oct 26, 2012         20000000.0      17530219.0    5.597567e+07
#
#         end_gross
# 0    1.175690e+08
# 1    1.222959e+09
# 2    2.588073e+07
# 3    1.574132e+07
# 4    1.283884e+09
# ..            ...
# 750  1.985443e+08
# 751 -1.156645e+07
# 752  6.763271e+07
# 753  4.321444e+07
# 754  5.350589e+07
#
# [755 rows x 23 columns]

# %%
last_data['Rotten Tomatoes'] = last_data['Rotten Tomatoes'].replace({'%': ''}, regex=True).astype(float)

# %%
last_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 755 entries, 0 to 754
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         755 non-null    int64
#  1   ID                 755 non-null    int64
#  2   movie              755 non-null    object
#  3   Year               755 non-null    int64
#  4   Age                743 non-null    object
#  5   IMDb               755 non-null    float64
#  6   Rotten Tomatoes    755 non-null    float64
#  7   Netflix            755 non-null    int64
#  8   Hulu               755 non-null    int64
#  9   Prime Video        755 non-null    int64
#  10  Disney+            755 non-null    int64
#  11  Type               755 non-null    int64
#  12  Directors          747 non-null    object
#  13  Genres             755 non-null    object
#  14  Country            755 non-null    object
#  15  Language           754 non-null    object
#  16  Runtime            755 non-null    float64
#  17  id                 755 non-null    int64
#  18  release_date       755 non-null    object
#  19  production_budget  755 non-null    float64
#  20  domestic_gross     755 non-null    float64
#  21  worldwide_gross    755 non-null    float64
#  22  end_gross          755 non-null    float64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 141.6+ KB

# %%
last_data.sort_values('Rotten Tomatoes', ascending = False)
# Out:
#      Unnamed: 0     ID                movie  Year  Age  IMDb  Rotten Tomatoes  \
# 750       16251  16252         Mary Poppins  1964  all   7.8            100.0
# 743         148    149           The Square  2013  NaN   8.1            100.0
# 744        4562   4563  The Sweet Hereafter  1997  18+   7.5            100.0
# 745       16233  16234          Toy Story 2  1999  all   7.9            100.0
# 746        3693   3694    Sands of Iwo Jima  1949  NaN   7.1            100.0
# ..          ...    ...                  ...   ...  ...   ...              ...
# 623        2043   2044                 Zoom  2006   7+   4.4              3.0
# 624        7339   7340      Bless the Child  2000  18+   5.1              3.0
# 625        7495   7496         The Darkness  2016  13+   4.4              3.0
# 693        4208   4209              Getaway  2013  13+   4.4              2.0
# 694        6938   6939   Strange Wilderness  2008  18+   5.3              2.0
#
#      Netflix  Hulu  Prime Video  ...  \
# 750        0     0            0  ...
# 743        1     1            1  ...
# 744        0     0            1  ...
# 745        0     0            0  ...
# 746        0     1            0  ...
# ..       ...   ...          ...  ...
# 623        1     0            0  ...
# 624        0     0            1  ...
# 625        0     0            1  ...
# 693        0     1            0  ...
# 694        0     0            1  ...
#
#                                             Genres  \
# 750                  Comedy,Family,Fantasy,Musical
# 743                                   Comedy,Drama
# 744                                          Drama
# 745      Animation,Adventure,Comedy,Family,Fantasy
# 746                       Action,Drama,Romance,War
# ..                                             ...
# 623  Action,Adventure,Comedy,Family,Fantasy,Sci-Fi
# 624                    Crime,Drama,Horror,Thriller
# 625                        Horror,Mystery,Thriller
# 693                          Action,Crime,Thriller
# 694                               Adventure,Comedy
#
#                                          Country                Language  \
# 750                                United States                 English
# 743  Sweden,Germany,France,Denmark,United States  Swedish,English,Danish
# 744                                       Canada                 English
# 745                                United States  English,Arabic,Spanish
# 746                                United States                 English
# ..                                           ...                     ...
# 623                                United States                 English
# 624                        United States,Germany                 English
# 625             Spain,United States,France,Italy          English,French
# 693                                United States         English,Spanish
# 694                                United States                 English
#
#     Runtime   id  release_date  production_budget  domestic_gross  \
# 750   139.0   17  Aug 26, 1964          6000000.0     102272145.0
# 743   151.0  100  Oct 25, 2013          1500000.0        124244.0
# 744   112.0   41  Oct 10, 1997          5000000.0       4306697.0
# 745    92.0   40  Nov 19, 1999         90000000.0     245852179.0
# 746   100.0   30  Dec 14, 1949          1000000.0       7800000.0
# ..      ...  ...           ...                ...             ...
# 623    93.0   26  Aug 11, 2006         35000000.0      11989328.0
# 624   107.0   78  Aug 11, 2000         40000000.0      29374178.0
# 625   101.0   98  May 13, 2016          4000000.0      10753574.0
# 693   123.0   20  Aug 30, 2013         18000000.0      10501938.0
# 694    87.0   64   Feb 1, 2008         20000000.0       6575282.0
#
#     worldwide_gross    end_gross
# 750     102272145.0  198544290.0
# 743        176262.0   -1199494.0
# 744       7951247.0    7257944.0
# 745     511358276.0  667210455.0
# 746       7800000.0   14600000.0
# ..              ...          ...
# 623      12506188.0  -10504484.0
# 624      40435694.0   29809872.0
# 625      10898293.0   17651867.0
# 693      11813989.0    4315927.0
# 694       6947084.0   -6477634.0
#
# [755 rows x 23 columns]

# %%
last_data['Netflix'].value_counts() #1 = yes it is on
# Out:
# 0    452
# 1    303
# Name: Netflix, dtype: int64

# %%
last_data['Hulu'].value_counts()
# Out:
# 0    633
# 1    122
# Name: Hulu, dtype: int64

# %%
last_data['Prime Video'].value_counts()
# Out:
# 0    456
# 1    299
# Name: Prime Video, dtype: int64

# %%
last_data['Disney+'].value_counts()
# Out:
# 0    621
# 1    134
# Name: Disney+, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
numofmovie = [303, 122, 299, 134]
nameofplatform = ['Netflix', 'Hulu', 'Prime Video', 'Disney+']

# %%
import numpy as np

# %%
x = nameofplatform
y = numofmovie
plot_one_fig, plot_one_ax = plt.subplots(figsize = (15, 8))

plot_one_ax.bar(x,y)
plot_one_ax.set_title('Number of Movies on Different Platforms', fontsize=30)
plot_one_ax.set_xlabel('Platforms', fontsize=15)
plot_one_ax.set_ylabel('Number of Movies', fontsize=15)
x_pos = np.arange(len(nameofplatform))
plt.bar(x_pos, numofmovie, color=['red', 'limegreen', 'midnightblue', 'cornflowerblue'])
# Out:
# <BarContainer object of 4 artists>

# %%
labels = ['Netflix', 'Hulu', 'Prime Video', 'Disney+']
movies = [303, 122, 299, 134]
tvshows = [228, 454, 375, 24]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize = (15, 8))
ax.bar(x - width/2, movies, width, label='Movies', color= 'midnightblue')
ax.bar(x + width/2, tvshows, width, label='TV Shows', color= 'cornflowerblue')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Movies and TV Shows', fontsize=15)
ax.set_title('Number of Movies and TV Shows Available Across Different Platforms',fontsize=25)
ax.set_xticks(x)
ax.set_xticklabels(labels, fontsize=15)
ax.legend()


plt.show()

# %%
nonstream_eg.describe() #not on stream avg end gross
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  4291.000000       4.291000e+03    4.291000e+03     4.291000e+03
# mean     50.186204       3.243548e+07    4.344763e+07     9.425513e+07
# std      28.836660       4.005439e+07    6.501099e+07     1.661247e+08
# min       1.000000       1.100000e+03    4.010000e+02     4.010000e+02
# 25%      25.000000       6.000000e+06    4.000000e+06     7.833752e+06
# 50%      50.000000       1.940000e+07    2.096664e+07     3.346201e+07
# 75%      75.000000       4.100000e+07    5.507109e+07     1.044966e+08
# max     100.000000       3.500000e+08    9.366622e+08     2.208208e+09
#
#           end_gross
# count  4.291000e+03
# mean   1.052673e+08
# std    2.017095e+08
# min   -1.574753e+08
# 25%    1.243676e+06
# 50%    3.250004e+07
# 75%    1.200958e+08
# max    2.683973e+09

# %%
onstream_eg.describe() #on stream avg end gross
# Out:
#                id  production_budget  domestic_gross  worldwide_gross  \
# count  943.000000       9.430000e+02    9.430000e+02     9.430000e+02
# mean    51.076352       4.130498e+07    5.904326e+07     1.303679e+08
# std     28.907321       5.368128e+07    8.946631e+07     2.355588e+08
# min      1.000000       3.000000e+04    3.880000e+02     7.030000e+02
# 25%     26.000000       7.150000e+06    5.978240e+06     1.074536e+07
# 50%     51.000000       2.000000e+07    2.808716e+07     4.715865e+07
# 75%     76.500000       5.000000e+07    7.216403e+07     1.408390e+08
# max    100.000000       4.250000e+08    7.605076e+08     2.776345e+09
#
#           end_gross
# count  9.430000e+02
# mean   1.481062e+08
# std    2.803931e+08
# min   -8.905748e+07
# 25%    5.436333e+06
# 50%    4.744992e+07
# 75%    1.627550e+08
# max    3.111853e+09

# %%
eg_value = [148.1062, 105.2673]
eg_x = ['On Streaming Platforms', 'Not On Streaming Platforms']

# %%
x = eg_x
y = eg_value
plot_one_fig, plot_one_ax = plt.subplots(figsize = (15, 8))

plot_one_ax.bar(x,y)
plot_one_ax.set_title('Avg Gross Box Office Profit of Movies Now On Streaming Platforms VS Not On Streaming Platforms', fontsize=20)
plot_one_ax.set_xlabel('Streaming', fontsize=15)
plot_one_ax.set_ylabel('Gross Profit (In Millions)', fontsize=15)
x_pos = np.arange(len(x))
plt.bar(x_pos, y, color=['orchid', 'powderblue'])
# Out:
# <BarContainer object of 2 artists>

# %%
dfbudgetfilter[dfbudgetfilter.movie == 'The Signal']
# Out:
#       id  release_date       movie  production_budget  domestic_gross  \
# 5718  19  Feb 22, 2008  The Signal            50000.0        251150.0
# 4525  26  Jun 13, 2014  The Signal          4000000.0        600896.0
#
#       worldwide_gross  end_gross  Year
# 5718         406299.0   607449.0  2008
# 4525        2665322.0  -733782.0  2014

# %%
dfnon = df[~df['movie'].isin(df_count_list)]
dfnon
# Out:
#      id  release_date                                 movie  \
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 42   43  Dec 19, 1997                               Titanic
# 33   34  Jun 12, 2015                        Jurassic World
# 66   67   Apr 3, 2015                             Furious 7
# 4     5  Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi
# ..   ..           ...                                   ...
# 607   8   Sep 2, 2005                    A Sound of Thunder
# 352  53  Apr 27, 2001                        Town & Country
# 404   5  Aug 16, 2002          The Adventures of Pluto Nash
# 341  42  Jun 14, 2019           Men in Black: International
# 2     3   Jun 7, 2019                          Dark Phoenix
#
#      production_budget  domestic_gross  worldwide_gross     end_gross
# 5          306000000.0     936662225.0     2.053311e+09  2.683973e+09
# 42         200000000.0     659363944.0     2.208208e+09  2.667572e+09
# 33         215000000.0     652270625.0     1.648855e+09  2.086125e+09
# 66         190000000.0     353007020.0     1.518723e+09  1.681730e+09
# 4          317000000.0     620181382.0     1.316722e+09  1.619903e+09
# ..                 ...             ...              ...           ...
# 607         80000000.0       1900451.0     6.300451e+06 -7.179910e+07
# 352        105000000.0       6712451.0     1.036477e+07 -8.792278e+07
# 404        100000000.0       4411102.0     7.094995e+06 -8.849390e+07
# 341        110000000.0       3100000.0     3.100000e+06 -1.038000e+08
# 2          350000000.0      42762350.0     1.497624e+08 -1.574753e+08
#
# [4291 rows x 7 columns]

# %%
dfnon.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  4291.000000       4.291000e+03    4.291000e+03     4.291000e+03
# mean     50.186204       3.243548e+07    4.344763e+07     9.425513e+07
# std      28.836660       4.005439e+07    6.501099e+07     1.661247e+08
# min       1.000000       1.100000e+03    4.010000e+02     4.010000e+02
# 25%      25.000000       6.000000e+06    4.000000e+06     7.833752e+06
# 50%      50.000000       1.940000e+07    2.096664e+07     3.346201e+07
# 75%      75.000000       4.100000e+07    5.507109e+07     1.044966e+08
# max     100.000000       3.500000e+08    9.366622e+08     2.208208e+09
#
#           end_gross
# count  4.291000e+03
# mean   1.052673e+08
# std    2.017095e+08
# min   -1.574753e+08
# 25%    1.243676e+06
# 50%    3.250004e+07
# 75%    1.200958e+08
# max    2.683973e+09
